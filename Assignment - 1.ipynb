# %% [markdown]
# ## Assignment - 1
#
# **1. In the Below Elements Which of Them Are Values or An Expression? Eg:- Values Can Be Integer Or String And Expressions Will Be Mathematical Operators.**
#
#     *
#     'Hello'
#     -87.8
#     -
#     /
#     +
#     6
#
# **Answer:**
#
# *    **Values are :**
#     - 'Hello
#     -  87.8
#     -  6
#
#
# *    **Expression are:**
#     -  *
#     -  -
#     -  /
#     -  +
#
# **2. What Is the Difference Between String and Variable?**
#
# **Answer:**
#
# * **String**
# - String is datatype class in python. String content can be enclosed by single (‘  ‘) or double quotes (“  “).
# - Backslash use to escape work. String content inside triple quote (“””   “””) use for multiple line of string.
# - We can parse string with the help of string slicing functions.
#
# * **Variables**
#
# - Variables are noting but container which contain or store values, expression, strings etc.
# - Variable can be assigned for strings.
#     Eg.
#     a = ‘Hello Word!’
# - Reusability of specific value, expression, or strings enhanced due to variables.
#
# **3. Describe Three Different Data Types.**
#
#
# **Answer:**
#
#
# *    **1.	List : [  ]**
#
#     List is an ordered sequence of items. It can hold integer, float , complex number and strings too. Its very flexible data type. Content or data store in list by enclosing into square bracket [   ]. In python we can enclose list inside list , and its possible to make blank list too.
#     List can be parse by using list slicing method. In list slicing index start from 0 to till end however lower bound is considered in string and upper bound is excluding.
#     List have their own built-in functions such as sort, append, insert, extend remove, reverse and many more ..
#     - Example:
#     L1 =                     [ 1 ,55, 70, 605, 71, 87, 10]
#
# *    **2.	Dictionary: {  }**
#
#     Dictionary is ordered collection of data in python which follows key and value pair functionality. Data or content stored in dictionary by enclosed them into two curly brackets. {  }. We can assign any datatype inside dictionary. Dictionary slicing can be done by parsing key and values.
#     To convert data (which is in key and value pair format) into dictionary there is one built in function called ‘Dict( )’.
#
#     - Example:
#     dict1 = {"Name":'Aumsai', 'Course':'Full stack data science', 'Email_ID':'aumsaiw84@gmail.com'}
#
#
# *    **3.Strings: (‘ ’)**
#
#     Strings are object that contain sequence of character of data. Data store or content in string by enclosed in single quote (‘ ’) or double quote (“ ”). We can perform string slicing by parsing through indexes. For strings index start from 0 to till end. While slicing lower bound is included and upper bound is excluded one. We can assign variable for string to enhance reusability of code or string.
#     In string operator ‘+’ will use to concatenate string with other string but we try concatenation for string and integer its not possible. For operator * string will be multiplying into number of times equal to given integer.
#
#     - Example: 'Hello World!'
#
# **4.What Is an Expression Made Up Of? What Do All Expressions Do?**
#
# **Answer:**
#
# - Expression is combination of operator and operand. Expression in python evaluate the data or values.
#
#
# - Example: 5 + 1
#
#
#
# - In this example 5 and 1 are operand and + is Arithmetic operator.
#
#   This combination will evaluate result into 6. This called expression in python.
#
#
# **5. This Assignment Statements, Like Spam = 10. What Is The Difference Between An Expression And A Statement?**
#
#
# **Answer :**
#
# - In assignment statement spam = 10, Spam is nothing but variable and with assigned value 10 .
#
# **Statement**
#
# - Instruction written in code for execution is nothing but statement. There are multiple types of statement in python such as Assignment statement, looping statement and conditional statement.
#
# **Expression**
#
# - Expression is combination of operator and operand. Expression in python evaluate data. There are many types of Expression such as constant expression, floating expression logical expression etc.
#
#
# **6. After Running The Following Code, What Does The Variable Bacon Contain?**
#     Bacon = 22
#     Bacon + 1
#
# **Answer:**
#
#
# *    **Bacon = 22**
#
#
# - Bacon is variable with value 22.
#
# *    **Bacon + 1**
# (After execution result is 23)
#
# - Bacon variable is still have value 22, new result (23) is not assigned to any variable yet.
#
#
# **7. What should the values of the following two terms be?**
#
# - 'Spam' + 'Spamspam'
# - 'Spam' * 3
#
# **Anwer:**
#
# - We are concatenating ‘Spam’ + ‘Spamspam’ string with another string result into ‘SpamSpamspam’
# - In second String is multiply by integer ‘Spam’*3 result into ‘SpamSpamSpam’
#
#
#
# **8. Why Is Eggs A Valid Variable Name While 100 Is Invalid?**
#
#
# **Answer:**
#
# - We cannot assign integer as variable to value.
#
#
#
#
# **9. What Three Functions Can Be Used To Get The Integer, Floating-Point Number, Or String Version Of A Value?**
#
#
#
# **Answer:**
#
# - Int(), float  and str() these three built in function can be used for typecasting.
#
#
#
#
#
# **10. Why Does This Expression Cause An Error? How Can You Fix It?**
#
# - 'I Have Eaten ' + 99 + ' Burritos.'
#
#
# **Answer:**
#
#
# - Concatenation can be possible for string with other string not with the combination of string and integer.
# - To fix this issue, we can put 99 into single (' ') or double (" ") quote to typecast into string.
