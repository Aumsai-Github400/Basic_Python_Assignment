# %% [markdown]
# # Assignment  - 2
#
#
#
# **1.What are the two values of the Boolean data type? How do you write them?**
#
# **Answer:**
#
# - Python boolean type is one of the built-in data types provided by Python, which are defined by the True or False keywords. Normally this data type is used for comparing values in expression or to change behaviour of expression.
# - A = True
#
#     Type(A) (After execution result will be “bool”)
# - B = False
#
#     Type(B) (After execution result will be “bool”)
#
# - 0 == 0 (After execution result will be “true”)
# - 0 == 1 (After execution result will be “False”)
#
#     True and False these are two values of Boolean data type.
#
#
#
# **2. What are the three different types of Boolean operators?**
#
# **Answer:**
#
#     In python Boolean data type use for comparing expression or to change behaviour of expression.
#     This data manipulation can be done with the help of Boolean Operators.
# - Or
# - And
# - Not
# - == (Equivalent)
# - != (not Equivalent)
#
# **3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).**
#
# **Answer:**
#
# - True and True Result is True.
#
# - True and False Result is False.
#
# - False and True Result is False.
#
# - False and False Result is False.
#
# - True or True Result is True.
#
# - True or False Result is True.
#
# - False or True Result is True.
#
# - False or False Result is False.
#
# - not True Result is False.
#
# - not False Result is True.
#
# **4. What are the values of the following expressions?**
#
# - (5 > 4) and (3 == 5)
# - not (5 > 4)
# - (5 > 4) or (3 == 5)
# - not ((5 > 4) or (3 == 5))
# - (True and True) and (True == False)
# - (not False) or (not True)
#
# **Answer:**
# - (5 > 4) and (3 == 5) Result is False
# - not (5 > 4) Result is False
# - (5 > 4) or (3 == 5) Result is True
# - not ((5 > 4) or (3 == 5)) Result is False
# - (True and True) and (True == False) Result is False
# - (not False) or (not True) Result is True
#
#
# **5. What are the six comparison operators?**
# **Answer:**
#
# *   **Comparing operators are as follows:**
#
#
# - == (Equivalent)
# - != (Not Equivalent)
# - < (Less than)
# - (>) (Greater than)
# - <= (Less than equal to)
# - (>=) (Greater than equal to)
#
# **6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.**
#
# **Answer:**
#
# * **Boolean operator(==)**
#
#     Boolean operator (==) equivalent is comparing operator used to compare one value with other value, result into Boolean either True or False.
# - Eg  5 == 0 (After execution Result is False)
#
#
# * **Assignment operator(=)**
#
#     Assignment operator (=) is used to define variable
# - Eg  a = “Hello World!”
#
#
# **7. Identify the three blocks in this code:**
#
# spam = 0
#
# if spam == 10:
#
#     print('eggs')
#
# if spam > 5:
#
#     print('bacon')
#
# else:
#     print('ham')
#
#     print('spam')
#
#     print('spam')
#
# **Answer:**
#
# - There are three blocks in this code
#     1st block is 1st if statement.
#
#     2nd block is 2nd if statement.
#
#     3rd block is else statement.
#
#
# **8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.**
#
# **Answer:**
#
#     spam = int(input("Enter Spam value"))
#
#     if spam == 1:
#
#         print ("Hello")
#
#     elif spam == 2:
#
#         print ("Howdy")
#
#     else:
#
#         print ("Greetings!")
#
#
# **9.If your programme is stuck in an endless loop, what keys you’ll press?**
#
# **Answer:**
#
# - Press CTRL-C to stop a program stuck in an infinite loop.
#
# **10. How can you tell the difference between break and continue?**
#
# **Answer:**
#
# - Break statement will break loop and enter into just after loop or execute next execution.
#
# -    Continue statement will take cursor to start of loop until condition get satisfied.
#
# **11. In a for loop, what is the difference between range (10), range (0, 10), and range (0, 10, 1)?**
#
# **Answer:**
#
# - Range is built in function work as generator takes integer as an argument and result into integer itself. All three condition as generating result and output is integer from 0 – 9 in incremental order. Range function take 3 argument (start, stop [step]). By default, start point is 0, stop point is given (10) and step is 1.
# - Range (10) : start is (0) by default , stop is given as 10 and step is by default (1).
# - Range (0-10): start is given as 0 , stop is given as 10 and step is by default (1).
# - Range (0,10,1): start is given as 0 , stop is given as 10 and step is given as 1.
#
# **12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.**
#
# **Answer:**
#
# * **For loop**
#
#     for i in range(1,11):
#         print (i)
#
# * **While loop**
#
#     i = 1
#     while i >= 1 and i < 11:
#         print (i)
#         i = i + 1
#
# **13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?**
#
# **Answer:**
#
#     Import spam module.
#     For calling function Spam.bacon()
#
# * **Code is below**
#
#     import spam
#
#     spam.bacon()
