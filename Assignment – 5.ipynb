# %% [markdown]
# # Assignment – 5
#
#
# **1.What does an empty dictionary's code look like?**
#
# **Answer:**
#
#     Two curly brackets , {   }
#
#
# **2. What is the value of a dictionary value with the key 'foo' and the value 42?**
#
# **Answer:**
#
#     {‘foo’:42}
#
#
# **3. What is the most significant distinction between a dictionary and a list?**
#
# **Answer:**
#
#     Object store in dictionary are unordered and object stored in list are ordered.
#
#
# **4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?**
#
# **Answer:**
#
# *    **Code as below**
#
#     spam = {'bar':100}
#
#     spam['foo']
#
#
# *    **Result**
#
#
#     KeyError: 'foo'
#
# **5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?**
#
#
# **Answer:**
#
#     Let consider dictionary as spam = {‘cat’:45}
#
# - ‘cat’ in spam: gives bool type result is true or false.
# - ‘cat’ in Spam.keys(): gives bool type result is true or false
#
# - No difference operator is checking is key in dictionary or not
#
# **6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?**
#
# **Answer:**
#
# - 'cat' in spam checks whether there is a 'cat' key in the dictionary.
#
# - While 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.
#
# **7. What is a shortcut for the following code?**
#
#     if 'color' not in spam:
#
#     spam['color'] = 'black'
#
# **Answer:**
#
#
#     There is one built in function or method to called setdefault(keys, values).
#
#     Spam.setdefault('colour','black')
#
# **8. How do you "pretty print" dictionary values using which module and function?**
#
# **Answer:**
#
#
# - While working on dictionary, if is too long and not in good format to read then it will be defficult to read and work.
#
# - There is one module called pprint in python to handle such issue.
#
#
# - Module : pprint
#
#
# - Function : pprint.pprint()
